# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('geoplanet_places_7.4.0.tsv', sep='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5332310 entries, 0 to 5332309
# Data columns (total 6 columns):
# WOE_ID       int64
# ISO          object
# Name         object
# Language     object
# PlaceType    object
# Parent_ID    int64
# dtypes: int64(2), object(4)
# memory usage: 244.1+ MB

# %%
df.head(100)
# Out:
#       WOE_ID ISO                      Name Language PlaceType  Parent_ID
# 0   23424994  CY  Cyprus Greek Cypriot Rep      ENG     State   26812346
# 1   23424995  CY               Cyprus TRNC      ENG     State   26812346
# 2   12577963  CY                 Famagusta      UNK    County   23424994
# 3   12577964  CY                   Larnaca      UNK    County   23424994
# 4   12577965  CY                  Limassol      UNK    County   23424994
# 5   12577966  CY                    Paphos      UNK    County   23424994
# 6   12577968  CY                 Famagusta      ENG    County   23424995
# 7   12577969  CY                   Kyrenia      ENG    County   23424995
# 8   12577971  CY                   Nicosia      ENG    County   23424995
# 9     841103  CY                  Akanthou      UNK      Town   12577968
# 10    841154  CY                      Asha      UNK      Town   12577968
# 11    841162  CY                  Athienou      ENG      Town   12577964
# ...

# %%
df = df[df.PlaceType != 'Zip']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1934474 entries, 0 to 5332309
# Data columns (total 6 columns):
# WOE_ID       int64
# ISO          object
# Name         object
# Language     object
# PlaceType    object
# Parent_ID    int64
# dtypes: int64(2), object(4)
# memory usage: 103.3+ MB

# %%
df.head(100)
# Out:
#        WOE_ID ISO                                      Name Language  \
# 0    23424994  CY                  Cyprus Greek Cypriot Rep      ENG
# 1    23424995  CY                               Cyprus TRNC      ENG
# 2    12577963  CY                                 Famagusta      UNK
# 3    12577964  CY                                   Larnaca      UNK
# 4    12577965  CY                                  Limassol      UNK
# 5    12577966  CY                                    Paphos      UNK
# 6    12577968  CY                                 Famagusta      ENG
# 7    12577969  CY                                   Kyrenia      ENG
# 8    12577971  CY                                   Nicosia      ENG
# 9      841103  CY                                  Akanthou      UNK
# 10     841154  CY                                      Asha      UNK
# 11     841162  CY                                  Athienou      ENG
# 12     841163  CY                                     Athna      ENG
# ...

# %%
df[df.WOE_ID == 23424768]
# Out:
#            WOE_ID ISO    Name Language PlaceType  Parent_ID
# 3703721  23424768  BR  Brasil      POR   Country          1

# %%
df = df[df.PlaceType == 'Country']

# %%
df.head()
# Out:
#            WOE_ID ISO                   Name Language PlaceType  Parent_ID
# 57       26812346  CY                 Cyprus      ENG   Country          1
# 838      23424966  ST  Sao Tome and Principe      ENG   Country          1
# 34252    23424975  GB         United Kingdom      ENG   Country          1
# 1976434  23424974  UG                 Uganda      ENG   Country          1
# 1976928  23424805  EE                  Eesti      UNK   Country          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 57 to 5331984
# Data columns (total 6 columns):
# WOE_ID       247 non-null int64
# ISO          246 non-null object
# Name         247 non-null object
# Language     247 non-null object
# PlaceType    247 non-null object
# Parent_ID    247 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 13.5+ KB

# %%
df.to_csv('Countries_WOE_ID.csv')
